# %% [markdown]
# # Eksploratorna analiza skupa podataka

# %%
import functools
import warnings

import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

from mpl_toolkits.mplot3d.axes3d import Axes3D

from wordcloud import WordCloud, STOPWORDS

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from textblob import TextBlob
#import squarify 

# %matplotlib inline

# %% [markdown]
# Učitavamo *train* podatakate te na njima radimo osnovnu analizu podataka.

# %%
data = pd.read_csv('train.tsv', sep='\t')

# %%
test=pd.read_csv('test.tsv', sep='\t')

# %%
data.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
data.shape, test.shape
# Out:
# ((1482535, 8), (693359, 7))

# %% [markdown]
# Skup za treniranje ima 1482535 redaka i 8 stupaca, dok skup za testiranje ima 693359 redaka i 7 stupaca.
#
# Pokažimo tipove varijabli.

# %%
data.info()
#train.drop_duplicates(keep="first") - nema duplikata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
# train_id             1482535 non-null int64
# name                 1482535 non-null object
# item_condition_id    1482535 non-null int64
# category_name        1476208 non-null object
# brand_name           849853 non-null object
# price                1482535 non-null float64
# shipping             1482535 non-null int64
# item_description     1482531 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 90.5+ MB

# %%
i = data.name.value_counts().size
print ('Number of distinct items names : ', i)
# Out:
# Number of distinct items names :  1225273

# %%
nb_cat = data.category_name.value_counts().size
print ('We have', nb_cat, 'different items categories.')
# Out:
# We have 1287 different items categories.

# %%
nb_brand = data.brand_name.value_counts().size
print ('We have', nb_brand, 'different items brands.')
# Out:
# We have 4809 different items brands.

# %%
#Imamo li NaN Vrijednosti?
data.isna().sum()
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          6327
# brand_name           632682
# price                     0
# shipping                  0
# item_description          4
# dtype: int64

# %%
#sns.set(style="ticks", color_codes=True)
#sns.pairplot(data)

# %%
#sns.set(style="ticks", color_codes=True)
#sns.pairplot(data,hue="price")

# %%
sns.catplot(x="category_name", y="price", data=data)

# %% [markdown]
# Prikaz mreže osi gdje je svaka varijabla povezana sa svakom.
# Dijagonalni grafovi prikazuju univarijantnu distribuciju svake varijable, dok preostali prostali međusonu vezu između pojedinih varijabli.

# %% [markdown]
# ## Analiza varijable *price*

# %%
data['price'].describe()
# Out:
# count    1.482535e+06
# mean     2.673752e+01
# std      3.858607e+01
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.700000e+01
# 75%      2.900000e+01
# max      2.009000e+03
# Name: price, dtype: float64

# %% [markdown]
# Cijena se nalazi u rasponu od 0 do 2009, sa prosječnom cijenom 26  i medianom 17 \$.

# %%
plt.figure(figsize=(10,10))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribucija cijene')
plt.hist(data['price'], color = 'blue', edgecolor = 'black',
    bins = 200)
plt.show()

# %% [markdown]
# Cijena prikazana ovom grafu ima težak desni rep, što će utjecati na na našu predikciju.

# %% [markdown]
# Odrežimo graf tako da gledamo cijene manje od 250\$.

# %%
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribucija cijene')
plt.hist(data['price'], color = 'blue', edgecolor = 'black',
    bins = 100,range=[0,250])
plt.show()

# %% [markdown]
# Koliko ima proizvoda sa cijenom većom od 100$?

# %%
(data['price']>75).sum()
# Out:
# 72541

# %%
72541/(len(data['price']))
# Out:
# 0.04893037938396058

# %% [markdown]
# Imamo 4.89% proizvoda sa cijenom većom od $75.

# %% [markdown]
# Kako izgleda graf logaritmiranih cijena?

# %%
data['price_log']=np.log(data['price']+1)

# %%
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Price log')
plt.ylabel('Frequency')
plt.title('Distribucija cijene')
plt.hist(data['price_log'], color = 'blue', edgecolor = 'black',
    bins = 100)
plt.show()

# %% [markdown]
# Logaritmiranjem cijene tranformiramo distribuciju tako da dobijemo model koji je balansiran, distribucija liči na normalnu.

# %% [markdown]
# ## Analiza varijable *item_condition_id*

# %% [markdown]
# Ovisi li cijena o *item_condition_id* varijabli?

# %%
#Uzmimo cijene manje od 100$
df = data[data['price']<100]
my_plot = []
for i in data['item_condition_id'].unique():
    my_plot.append(df[df['item_condition_id']==i]['price'])

fig, axes = plt.subplots(figsize=(20, 15))
bp = axes.boxplot(my_plot,vert=True,patch_artist=True,labels=range(1,6)) 

colors = ['aqua', 'lightblue', 'yellowgreen', 'tan', 'pink']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

axes.yaxis.grid(True)

plt.title('BoxPlot price X item_condition_id', fontsize=15)
plt.xlabel('item_condition_id', fontsize=15)
plt.ylabel('price', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

del df

# %% [markdown]
# Analizom ovog grafa naslućujemo da nema značajne razlike cijene po *item_condition_id* kategorijama.

# %% [markdown]
# ### Analiza varijable *category_name*

# %%
plt.figure(figsize=(17,10))
sns.countplot(y = data.category_name, order = data.category_name.value_counts().iloc[:20].index,  orient = 'v')
plt.title('Top 20 categories', fontsize = 25)
plt.ylabel('Category name', fontsize = 20)
plt.xlabel('Number of product in the category', fontsize = 20)
# Out:
# Text(0.5, 0, 'Number of product in the category')

# %%
# Grupiranje po kategorijama
cat = pd.DataFrame(data.category_name.value_counts())
cat.reset_index(level = 0, inplace=True)
cat = cat.sort_values(by='category_name', ascending = False)
cat.columns =('category_name', 'size')
#cat #1287
#cat[cat['size']>3] #1112
#cat[cat['size']>10] #958
#cat[cat['size']>100] #603
cat[cat['size']>1000] #603
# Out:
#                                          category_name   size
# 0       Women/Athletic Apparel/Pants, Tights, Leggings  60177
# 1                        Women/Tops & Blouses/T-Shirts  46380
# 2                                   Beauty/Makeup/Face  34335
# 3                                   Beauty/Makeup/Lips  29910
# 4             Electronics/Video Games & Consoles/Games  26557
# 5                                   Beauty/Makeup/Eyes  25215
# 6    Electronics/Cell Phones & Accessories/Cases, C...  24676
# 7                                 Women/Underwear/Bras  21274
# 8                      Women/Tops & Blouses/Tank, Cami  20284
# 9                          Women/Tops & Blouses/Blouse  20284
# 10                      Women/Dresses/Above Knee, Mini  20082
# 11                             Women/Jewelry/Necklaces  19758
# 12                       Women/Athletic Apparel/Shorts  19528
# 13                       Beauty/Makeup/Makeup Palettes  19103
# 14                                   Women/Shoes/Boots  18864
# 15                              Beauty/Fragrance/Women  18628
# 16                               Beauty/Skin Care/Face  15836
# 17                 Women/Women's Handbags/Shoulder Bag  15328
# 18                                   Men/Tops/T-shirts  15108
# 19                           Women/Dresses/Knee-Length  14770
# 20                Women/Athletic Apparel/Shirts & Tops  14738
# 21                                 Women/Shoes/Sandals  14662
# 22                             Women/Jewelry/Bracelets  14497
# 23                                  Men/Shoes/Athletic  14257
# 24                       Kids/Toys/Dolls & Accessories  13957
# 25                   Women/Women's Accessories/Wallets  13616
# 26                            Women/Jeans/Slim, Skinny  13392
# 27                  Home/Home Décor/Home Décor Accents  13004
# 28                            Women/Swimwear/Two-Piece  12758
# 29                                Women/Shoes/Athletic  12662
# ..                                                 ...    ...
# 208           Beauty/Hair Care/Hair & Scalp Treatments   1254
# 209                     Home/Kitchen & Dining/Bakeware   1233
# 210    Women/Athletic Apparel/Skirts, Skorts & Dresses   1214
# 211                        Women/Coats & Jackets/Other   1175
# 212                  Kids/Diapering/Disposable Diapers   1165
# 213                         Kids/Diapering/Diaper Bags   1162
# 214       Electronics/TV, Audio & Surveillance/Gadgets   1153
# 215  Electronics/Video Games & Consoles/Video Gamin...   1151
# 216                        Kids/Girls (4+)/Accessories   1148
# 217                    Women/Women's Accessories/Belts   1136
# 218                          Other/Pet Supplies/Others   1136
# 219                       Women/Women's Handbags/Other   1116
# 221                  Handmade/Paper Goods/Scrapbooking   1078
# 220  Home/Home Appliances/Wine, Beer & Beverage Coo...   1078
# 222                   Women/Coats & Jackets/Motorcycle   1077
# 223                  Kids/Toys/Dress Up & Pretend Play   1074
# 224  Electronics/Computers & Tablets/iPad/Tablet/eB...   1073
# 225                    Men/Coats & Jackets/Windbreaker   1065
# 226                 Vintage & Collectibles/Book/Comics   1064
# 227                   Kids/Girls 2T-5T/Coats & Jackets   1062
# 228  Electronics/Cameras & Photography/Camera & Pho...   1057
# 229                     Sports & Outdoors/Fan Shop/MLB   1053
# 230                            Women/Maternity/Dresses   1041
# 231                                   Kids/Other/Other   1038
# 232                  Handmade/Bags and Purses/Wristlet   1031
# 233                     Sports & Outdoors/Apparel/Boys   1030
# 234                     Kids/Toys/Learning & Education   1025
# 235       Kids/Toys/Toy Remote Control & Play Vehicles   1020
# 236              Sports & Outdoors/Apparel/Accessories   1012
# 237                     Women/Maternity/Tops & Blouses   1007
#
# [238 rows x 2 columns]

# %% [markdown]
# Od ukupno 1287 kategorija, njih 958 ima više od 10 proizvoda, dok njih 603 ima više od 100 proizvoda.
#
# Dodatno, postoji 238 kategorija koje imaju više od 1000 proizvoda.
#
# Pogledajmo kakva je prosječna cijena po kategorijama.

# %%
group = data.groupby(data.category_name)
mean_price = group.price.mean()
mean_price = mean_price.to_frame()
mean_price.reset_index(level = 0, inplace=True)
mean_price

# Merging
cats = pd.merge(cat, mean_price, how='left', on = 'category_name')
cats=cats.sort_values(by='size',ascending=False)
cats.reset_index(drop=True, inplace=True)
cats
# Out:
#                                           category_name   size       price
# 0        Women/Athletic Apparel/Pants, Tights, Leggings  60177   34.392733
# 1                         Women/Tops & Blouses/T-Shirts  46380   19.386125
# 2                                    Beauty/Makeup/Face  34335   18.470890
# 3                                    Beauty/Makeup/Lips  29910   18.520846
# 4              Electronics/Video Games & Consoles/Games  26557   24.119667
# 5                                    Beauty/Makeup/Eyes  25215   14.621931
# 6     Electronics/Cell Phones & Accessories/Cases, C...  24676   13.174360
# 7                                  Women/Underwear/Bras  21274   18.636364
# 8                       Women/Tops & Blouses/Tank, Cami  20284   14.411655
# 9                           Women/Tops & Blouses/Blouse  20284   15.660102
# 10                       Women/Dresses/Above Knee, Mini  20082   21.866796
# 11                              Women/Jewelry/Necklaces  19758   25.587509
# 12                        Women/Athletic Apparel/Shorts  19528   18.547650
# 13                        Beauty/Makeup/Makeup Palettes  19103   25.561430
# 14                                    Women/Shoes/Boots  18864   42.645939
# 15                               Beauty/Fragrance/Women  18628   23.717790
# 16                                Beauty/Skin Care/Face  15836   22.482256
# 17                  Women/Women's Handbags/Shoulder Bag  15328   65.975535
# 18                                    Men/Tops/T-shirts  15108   18.352495
# 19                            Women/Dresses/Knee-Length  14770   30.094787
# 20                 Women/Athletic Apparel/Shirts & Tops  14738   22.450672
# 21                                  Women/Shoes/Sandals  14662   30.074069
# 22                              Women/Jewelry/Bracelets  14497   29.697938
# 23                                   Men/Shoes/Athletic  14257   66.526128
# 24                        Kids/Toys/Dolls & Accessories  13957   26.984882
# 25                    Women/Women's Accessories/Wallets  13616   34.854473
# 26                             Women/Jeans/Slim, Skinny  13392   21.618802
# 27                   Home/Home Décor/Home Décor Accents  13004   22.185020
# 28                             Women/Swimwear/Two-Piece  12758   21.988086
# 29                                 Women/Shoes/Athletic  12662   43.927421
# ...                                                 ...    ...         ...
# 1257             Home/Home Appliances/Garbage Disposals      1   60.000000
# 1258                      Handmade/Woodworking/Supplies      1    9.000000
# 1259                             Handmade/Knitting/Doll      1    5.000000
# 1260                               Handmade/Glass/Vases      1   11.000000
# 1261                        Handmade/Accessories/Mirror      1    5.000000
# 1262                       Handmade/Housewares/Bathroom      1   39.000000
# 1263                     Handmade/Books and Zines/Comic      1   13.000000
# 1264                                  Handmade/Art/Aceo      1   12.000000
# 1265                           Kids/Safety/Crib Netting      1   15.000000
# 1266          Vintage & Collectibles/Paper Ephemera/Map      1   26.000000
# 1267              Handmade/Ceramics and Pottery/Jewelry      1   19.000000
# 1268           Vintage & Collectibles/Antique/Furniture      1  195.000000
# 1269                  Handmade/Knitting/Bags and Purses      1   36.000000
# 1270     Vintage & Collectibles/Furniture/Entertainment      1    9.000000
# 1271           Vintage & Collectibles/Furniture/Storage      1   55.000000
# 1272                          Handmade/Accessories/Cozy      1   29.000000
# 1273                 Kids/Diapering/Washcloths & Towels      1    4.000000
# 1274                          Handmade/Accessories/Belt      1    8.000000
# 1275                  Home/Furniture/Bathroom Furniture      1   16.000000
# 1276                                Handmade/Quilts/Bed      1   25.000000
# 1277                           Handmade/Furniture/Shelf      1   10.000000
# 1278                          Handmade/Jewelry/Clothing      1    4.000000
# 1279                       Handmade/Patterns/Embroidery      1   10.000000
# 1280                                 Handmade/Toys/Bear      1   11.000000
# 1281                          Home/Home Décor/Doorstops      1    8.000000
# 1282                   Home/Home Appliances/Dishwashers      1    6.000000
# 1283                               Handmade/Quilts/Trim      1    5.000000
# 1284                           Handmade/Furniture/Other      1   13.000000
# 1285                        Handmade/Geekery/Housewares      1   10.000000
# 1286                            Handmade/Knitting/Women      1    8.000000
#
# [1287 rows x 3 columns]

# %%
mean_price = mean_price.sort_values(by='price', ascending = False).head(20)
mean_price.reset_index(level = 0, inplace=True)

plt.figure(figsize=(17,20))
sns.barplot(x = 'price', y = 'category_name', data = mean_price, orient = 'h')
plt.title('Top 20 categories with higher mean price', fontsize = 30)
plt.ylabel('Categories', fontsize = 25)
plt.xlabel('Mean price', fontsize = 25)
# Out:
# Text(0.5, 0, 'Mean price')

# %%
mean_price_2 = pd.DataFrame(group.price.mean())
mean_price_2.reset_index(level = 0, inplace=True)

plt.figure(figsize =(12,7))
sns.kdeplot(mean_price_2.price, shade = True)
plt.title('Mean price by category distribution', fontsize = 20)
plt.xlabel('Mean price of each category', fontsize = 16)
# Out:
# C:\Users\Bojana\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 0, 'Mean price of each category')

# %% [markdown]
# ### Analiza varijable *brand_name*

# %% [markdown]
# S obzirom da prilično velik broj nedostajućih vrijednosti za stupac *brand_name*, nadopuniti ćemo neke vrijednosti iz stupca *name*, jer se tamo, bar koliko se može primijetiti iz ispisanih vrijednosti, često pojavljuje i ime marke.

# %%
brandovi2=data['brand_name']
brandovi1=test['brand_name']

# %%
brandovi1.nunique() #broj jedinstvenih imena brendova
# Out:
# 3900

# %%
svi_brandovi=set(brandovi1.values)
for y in brandovi2:
    svi_brandovi.add(y)
svi_brandovi = {x for x in svi_brandovi if pd.notna(x)}
len(svi_brandovi)
# Out:
# 5289

# %%
missing_brands = data.brand_name.isnull().sum()
missing_brands_test = test.brand_name.isnull().sum()
missing_brands, missing_brands_test
# Out:
# (632682, 295525)

# %% [markdown]
# Prolazimo kroz training set i tražimo podudaranja između imena i skupa svih brandova

# %%
def trazilica(objekt):
    brand=objekt[0]
    ime=objekt[1]
    if pd.isna(brand):
        for i in ime:
            if i in svi_brandovi:
                return ime
    if brand in svi_brandovi:
        return ime
    return brand
data['brand_name']=data[['brand_name', 'name']].apply(trazilica, axis=1)
test['brand_name']=test[['brand_name', 'name']].apply(trazilica, axis=1)

# %%
missing_brands = data.brand_name.isnull().sum()
missing_brands_test = test.brand_name.isnull().sum()
missing_brands, missing_brands_test
# Out:
# (489074, 228370)

# %% [markdown]
# Uspjeli smo popuniti 143608 *missing branda*.

# %%
plt.figure(figsize=(17,10))
sns.countplot(y = data.brand_name, order = data.brand_name.value_counts().iloc[:20].index, orient = 'v')
plt.title('Top 20 brands', fontsize = 25)
plt.ylabel('Brand name', fontsize = 20)
plt.xlabel('Number of product', fontsize = 20)
# Out:
# Text(0.5, 0, 'Number of product')

# %%
# Display Top 20 Expensive Brands By Mean Price

mean_price1 = data.groupby('brand_name', axis=0).mean()
df= pd.DataFrame(mean_price1.sort_values('price', ascending = False)['price'][0:20].reset_index())

plt.figure(figsize=(17,20))
sns.barplot(x = 'price', y = 'brand_name', data = df, orient = 'h')
plt.title('Top 20 brand with higher price', fontsize = 30)
plt.ylabel('Brands', fontsize = 25)
plt.xlabel('Mean price', fontsize = 25)
plt.show()


# Displayd frequency ratio of brand names
data['brand_name'].value_counts(1)
# Out:
# PINK                     0.063644
# Nike                     0.063591
# Victoria's Secret        0.056523
# LuLaRoe                  0.036505
# Apple                    0.020382
# FOREVER 21               0.017869
# Nintendo                 0.017658
# Lululemon                0.017130
# Michael Kors             0.016389
# American Eagle           0.015596
# Rae Dunn                 0.014479
# Sephora                  0.014322
# Coach                    0.012312
# Disney                   0.012190
# Bath & Body Works        0.012183
# Adidas                   0.012004
# Funko                    0.010869
# Under Armour             0.009956
# Sony                     0.009406
# Old Navy                 0.008904
# Hollister                0.008176
# Carter's                 0.007513
# Urban Decay              0.007307
# The North Face           0.007262
# Independent              0.006945
# Too Faced                0.006818
# Xbox                     0.006718
# Brandy Melville          0.006684
# Kate Spade               0.006367
# MAC                      0.006239
#                            ...
# Archie Comics            0.000001
# Amphibious Outfitters    0.000001
# Love Riche               0.000001
# Oxbow                    0.000001
# Nubian Heritage          0.000001
# La Redoute               0.000001
# China Glaze Co. Ltd.     0.000001
# Catit                    0.000001
# Giftcraft                0.000001
# Garfield & Marks         0.000001
# Tidy Cats                0.000001
# Zen Group                0.000001
# Rioni                    0.000001
# Vittorio St. Angelo      0.000001
# Obagi                    0.000001
# Pampers Baby Fresh       0.000001
# Myths                    0.000001
# McGuire Denim            0.000001
# Buckley Supply Co.       0.000001
# Cdc Clothing             0.000001
# Cinema Secrets           0.000001
# Silkies                  0.000001
# Floracraft               0.000001
# GoGroove Pal             0.000001
# Dora the Explorer        0.000001
# RED Valentino            0.000001
# Old Soles                0.000001
# Eminence                 0.000001
# Stuhrling Original       0.000001
# Gianfranco Ferre         0.000001
# Name: brand_name, Length: 4809, dtype: float64

# %%
#data['brand_name'].isna().sum() #632682
#data['has_brend'] = 1
#data.loc[~data['brand_name'].isna()] = 0
#data.head()

#datan=data.loc[data.brand_name.isna()==False]
#datan.reset_index(drop=True, inplace=True)
#datan

# %%
#bez NaN
#plt.figure(figsize=(17,10))
#sns.countplot(y = datan.brand_name, order = datan.brand_name.value_counts().iloc[:20].index, orient = 'v')
#plt.title('Top 20 brands', fontsize = 25)
#plt.ylabel('Brand name', fontsize = 20)
#plt.xlabel('Number of product', fontsize = 20)

# %%
data1 = data.loc[data.price>200]
data1.name = data1.name.str.upper()

wc = WordCloud(background_color="white", max_words=5000, stopwords=STOPWORDS, max_font_size= 50)

wc.generate(" ".join(str(s) for s in data1.name.values))

plt.figure(figsize=(20,12))
plt.title('What are the most expensive items', fontsize = 30)
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')

# %%
data1 = data.loc[data.price>200]
data1.brand_name = data1.brand_name.str.upper()

wc = WordCloud(background_color="white", max_words=5000, stopwords=STOPWORDS, max_font_size= 50)

wc.generate(" ".join(str(s) for s in data1.brand_name.values))

plt.figure(figsize=(20,12))
plt.title('What are the most expensive brands', fontsize = 30)
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')

# %% [markdown]
# Primjetili smo da se varijabla *category_name* sastoji od 3 levela. Razdvajanjem dobivamo 3 nova *featuresa* tako da svaki ima vrijednost jednog levela kategorije.

# %%
data["subcat1"] = data.category_name.str.extract("([^/]+)/[^/]+/[^/]+", expand=False)
data["subcat2"] = data.category_name.str.extract("[^/]+/([^/]+)/[^/]+", expand=False)
data["subcat3"] = data.category_name.str.extract("[^/]+/[^/]+/([^/]+)", expand=False)

# %%
# excluding NA group
print("Number of Main Categories = " + str(len(pd.unique(data["subcat1"]))-1))
print("Number of Sub Category 1 = " + str(len(pd.unique(data["subcat2"]))-1))
print("Number of Sub Category 2 = " + str(len(pd.unique(data["subcat3"]))-1))
# Out:
# Number of Main Categories = 10
# Number of Sub Category 1 = 113
# Number of Sub Category 2 = 870

# %%
list(pd.unique(data["subcat1"]))
# Out:
# ['Men',
#  'Electronics',
#  'Women',
#  'Home',
#  'Sports & Outdoors',
#  'Vintage & Collectibles',
#  'Beauty',
#  'Other',
#  'Kids',
#  nan,
#  'Handmade']

# %%
list(pd.unique(data["subcat2"]))
# Out:
# ['Tops',
#  'Computers & Tablets',
#  'Tops & Blouses',
#  'Home Décor',
#  'Jewelry',
#  'Other',
#  'Swimwear',
#  'Apparel',
#  'Collectibles',
#  'Makeup',
#  'Fragrance',
#  'Dresses',
#  'Office supplies',
#  'Shoes',
#  'Gear',
#  'Athletic Apparel',
#  'Cell Phones & Accessories',
#  'Jeans',
#  'Underwear',
#  'Skin Care',
#  'Toys',
#  "Women's Handbags",
#  'Video Games & Consoles',
#  'Coats & Jackets',
#  'Pants',
#  'Girls (4+)',
#  'Antique',
#  'Kitchen & Dining',
#  'Sweaters',
#  'Boys 0-24 Mos',
#  'Girls 0-24 Mos',
#  'Maternity',
#  'Bedding',
#  'Exercise',
#  'Trading Cards',
#  'Boys (4+)',
#  'Storage & Organization',
#  'Fan Shop',
#  'Girls 2T-5T',
#  "Men's Accessories",
#  'Boys 2T-5T',
#  "Women's Accessories",
#  'Daily & Travel items',
#  nan,
#  'Skirts',
#  'Hair Care',
#  'Pet Supplies',
#  'Book',
#  'Tools & Accessories',
#  'Team Sports',
#  'Home Appliances',
#  'Accessories',
#  'Bags and Purses',
#  'Sweats & Hoodies',
#  'Shorts',
#  'TV, Audio & Surveillance',
#  'Outdoors',
#  'Bath & Body',
#  'Car Seats & Accessories',
#  'Toy',
#  'Art',
#  'Seasonal Décor',
#  'Footwear',
#  'Housewares',
#  'Media',
#  'Cameras & Photography',
#  'Glass',
#  'Paper Goods',
#  'Cleaning Supplies',
#  'Books',
#  "Kids' Home Store",
#  'Electronics',
#  'Diapering',
#  'Bath',
#  'Children',
#  'Magazines',
#  'Artwork',
#  'Automotive',
#  'Serving',
#  'Clothing',
#  'Supplies',
#  'Feeding',
#  'Suits & Blazers',
#  'Golf',
#  'Music',
#  'Pets',
#  'Health & Baby Care',
#  'Nursery',
#  'Furniture',
#  'Geekery',
#  'Musical instruments',
#  'Books and Zines',
#  'Safety',
#  'Crochet',
#  'Home Decor',
#  'Holidays',
#  'Strollers',
#  'Pregnancy & Maternity',
#  'Needlecraft',
#  'Paper Ephemera',
#  'Car Audio, Video & GPS',
#  'Bathing & Skin Care',
#  'Dolls and Miniatures',
#  'Suits',
#  'Weddings',
#  'Others',
#  'Knitting',
#  'Patterns',
#  'Blazers & Sport Coats',
#  'Woodworking',
#  'Potty Training',
#  'Candles',
#  'Ceramics and Pottery',
#  'Quilts']

# %%
list(pd.unique(data["subcat3"]))
# Out:
# ['T-shirts',
#  'Components & Parts',
#  'Blouse',
#  'Home Décor Accents',
#  'Necklaces',
#  'Other',
#  'Two-Piece',
#  'Girls',
#  'Doll',
#  'Face',
#  'Women',
#  'Above Knee, Mini',
#  'School Supplies',
#  'Boots',
#  'Makeup Sets',
#  'Eyes',
#  'Backpacks & Carriers',
#  'Makeup Palettes',
#  'Tank, Cami',
#  'Sports Bras',
#  'Cell Phones & Smartphones',
#  'Chargers & Cradles',
#  'T-Shirts',
#  'Athletic',
#  'Cases, Covers & Skins',
#  'Pants, Tights, Leggings',
#  'One-Piece',
#  'Boot Cut',
#  'Bras',
#  'Stuffed Animals & Plush',
#  'Totes & Shoppers',
#  'Shirts & Tops',
#  'Consoles',
#  'Glass',
#  'Vest',
#  'Arts & Crafts',
#  'Capris, Cropped',
#  'Messenger & Crossbody',
#  'Shoes',
#  'Collectibles',
#  'Coffee & Tea Accessories',
#  'Brooch',
#  'Headsets',
#  'Rings',
#  'Shorts',
#  'Fleece Jacket',
#  'Dolls & Accessories',
#  'Crewneck',
#  'Jackets',
#  'Home Fragrance',
#  'Accessories',
#  'Tops & Blouses',
#  'Sheets & Pillowcases',
#  'Fitness technology',
#  'Dress Up & Pretend Play',
#  'Animation',
#  'Jewelry Boxes & Organizers',
#  'Games',
#  'NCAA',
#  'Electronics for Kids',
#  'Watches',
#  'Knee-Length',
#  'Wallets',
#  'Tracksuits & Sweats',
#  'Loafers & Slip-Ons',
#  'Pumps',
#  'Full Zip',
#  'Medical Supplies & Equipment',
#  nan,
#  'Slim, Skinny',
#  'Belts',
#  'Tapestries',
#  'Figurine',
#  'Lips',
#  'Mini',
#  'Fashion Sneakers',
#  'Dresses',
#  'Shampoo & Conditioner Sets',
#  'Video Gaming Merchandise',
#  'Top & T-shirts',
#  'Dogs',
#  'Shoulder Bag',
#  'Hobo',
#  'Nails',
#  'Comics',
#  'Household Supplies',
#  'Halter',
#  'Learning & Education',
#  'Makeup Brushes & Tools',
#  'Earrings',
#  'Baby Gyms & Playmats',
#  'Cardigan',
#  'Shipping Supplies',
#  'Collared',
#  'Panties',
#  'Jewelry',
#  'Sandals',
#  'Baseball & Softball',
#  'Casual Pants',
#  'Candles & Home Scents',
#  'Kitchen Appliances',
#  'Hooded',
#  'Cables & Adapters',
#  'Coats & Jackets',
#  'Keychain',
#  'Asymmetrical Hem',
#  'Wristlet',
#  'Clutch',
#  'Full-Length',
#  'Sweatshirt, Pullover',
#  'Casual Shorts',
#  'Gadgets',
#  'Fishing',
#  'Leggings',
#  'Jeans',
#  'iPad',
#  'Sports',
#  'Bath',
#  'Bracelets',
#  'Body',
#  'Socks',
#  'Sports Nutrition',
#  'Action Figure',
#  'Hats',
#  'Portable Audio & Accessories',
#  'Photo Albums & Frames',
#  'Party Supplies',
#  'Action Figures & Statues',
#  'Fitness accessories',
#  'Sunglasses',
#  'Photography',
#  'Eyewear',
#  'Jean Jacket',
#  'Halloween',
#  'Dining & Entertaining',
#  'Kitchen Utensils & Gadgets',
#  'Button-Front',
#  'Tops & T-Shirts',
#  'Backpack Style',
#  'Cleats',
#  'Health Care',
#  'Tunic',
#  'Ceramic',
#  'DVD',
#  'Cell Phone Accessories',
#  'Ink & Toner',
#  'Necklace',
#  'Personal Care',
#  'Digital Cameras',
#  'Bottles',
#  'Sticker',
#  'Jerseys',
#  'CD',
#  'Camera & Photo Accessories',
#  'Tote',
#  'Flats',
#  'Polo, Rugby',
#  'Styling Products',
#  'Household Cleaners',
#  'Blankets & Throws',
#  'Purse',
#  'Literature & Fiction',
#  'Bottoms',
#  'Peacoat',
#  'One-Pieces',
#  'V-Neck',
#  "Children's Books",
#  'Small Appliances',
#  'Football',
#  'Hair Accessories',
#  'Education & Teaching',
#  'Slippers',
#  'Swimwear',
#  "Kids' Room Décor",
#  'Duvet Covers & Sets',
#  'Track & Sweat Pants',
#  'Cosmetic Bags',
#  'Hair Color',
#  'All Other Sports',
#  'Maxi',
#  'Lamps& Accessories',
#  'Radio',
#  'Conditioners',
#  'NFL',
#  'Disposable Diapers',
#  'Beach Accessories',
#  'Straight, Pencil',
#  'Bathroom Accessories',
#  'Baby & Toddler Toys',
#  'Asymmetrical',
#  'Baby',
#  'Towels',
#  'Lifestyle & Cultures',
#  'Military',
#  'Turtleneck, Mock',
#  'Paintings',
#  'Building Toys',
#  'Button Down Shirt',
#  'Scarves & Wraps',
#  'Feet',
#  'Khakis, Chinos',
#  'Straight Leg',
#  'Book',
#  'MLB',
#  'Cowl Neck',
#  'Valentine',
#  'Hair Styling Tools',
#  'Poncho',
#  'Video Game',
#  'Desktops & All-In-Ones',
#  'Thanksgiving',
#  'Mid-Calf',
#  'Cloth Diapers',
#  'Mules & Clogs',
#  'Hobbies',
#  'Car Electronics & Accessories',
#  "Kids' Bedding",
#  'Tank',
#  'Electronics',
#  'Backpacks, Bags & Briefcases',
#  'Dress Pants',
#  'Cover-Ups',
#  'Painting',
#  'Screen Protectors',
#  'Boys',
#  'Cleansers',
#  'Comforters & Sets',
#  'Hair',
#  'Blu-Ray',
#  'Drives, Storage & Media',
#  'Kids',
#  'Bakeware',
#  'Mug',
#  'G-Strings & Thongs',
#  'Cape',
#  'Sweater',
#  'Headphones',
#  'Polo Shirt',
#  'Charm',
#  'Clothing & Closet Storage',
#  'Wall Decor',
#  'Scrapbooking',
#  'NBA',
#  'Handbag',
#  'Pacifiers & Accessories',
#  'Capri, Cropped',
#  'Ties',
#  '100 Years or Older',
#  'Pouch',
#  'Playards',
#  'Costume',
#  'Vacuums & Floor Care',
#  'Makeup Remover',
#  'Blazer',
#  'Brushes & Applicators',
#  "Men's Golf Clubs",
#  'Film Photography',
#  'Medical Books',
#  'Bottle-Feeding',
#  'Toy',
#  'Laptops & Netbooks',
#  'Vinyl',
#  'Collar',
#  'Garment Steamers',
#  'Clocks',
#  'Tools & Equipment',
#  'Cookbook',
#  'Pleated',
#  'Cards',
#  'Windbreaker',
#  'Bedding',
#  'Pants',
#  'Diaper Pails & Refills',
#  'Cup',
#  'Arts & Photography',
#  'Storage & Containers',
#  'VHS',
#  'Souvenir',
#  'Sets & Kits',
#  'Exterior Accessories',
#  'Home Office Furniture',
#  'Scrubs & Body Treatments',
#  'Classic, Straight Leg',
#  'Wine Accessories',
#  'Wrap',
#  'Food',
#  'Boxing & MMA',
#  'Luggage',
#  'Ring',
#  'Car Seats',
#  'Diaper Bags',
#  'Motorcycle',
#  'Shampoos',
#  'Hoodie',
#  'Knit Top',
#  'Henley',
#  'Drawings',
#  'Cookware',
#  'Electronic',
#  'Formal',
#  'Yoga & Pilates',
#  'Networking & Connectivity',
#  'Humidifiers',
#  'Sets',
#  'Dress Shirts',
#  'Writing',
#  'Volleyball',
#  'Styling Tools',
#  "Kids' Furniture, Décor & Storage",
#  'Puffer',
#  'Science',
#  'Bracelet',
#  'Christmas',
#  '50 To 75 Years',
#  'Game',
#  'Calendars',
#  'Batteries',
#  'Swings, Jumpers & Bouncers',
#  'Others',
#  'DVD & Blu-ray Players',
#  'Raincoat',
#  'Athletic Training',
#  'Hiking & Camping',
#  'Scoop Neck',
#  'Cargo',
#  'Breastfeeding',
#  'Pant Suit',
#  'Bowl',
#  'A-Line',
#  'Wind & Woodwind Instruments',
#  'Overalls',
#  'Dance',
#  'Bookmark',
#  'Kitchen & Table Linens',
#  'Waxing',
#  'Water Coolers & Filters',
#  'Sun',
#  'Work & Safety',
#  'Monitors',
#  'Air Fresheners',
#  'Lingerie',
#  'Wipes & Holders',
#  'Men',
#  'Pinback Button',
#  'Candles & Holders',
#  'Leg Warmers',
#  'Highchairs & Booster Seats',
#  'Camcorders',
#  'Puzzles',
#  'Tumbler',
#  'Vintage',
#  'Supplies',
#  'Business & Money',
#  'Bike & Skate',
#  'Turtleneck',
#  'Candle Holder',
#  'Satchel',
#  'Organization',
#  'Skirt',
#  'Bathroom Storage & Organization',
#  'Baskets',
#  'Stationery',
#  'Hair & Scalp Treatments',
#  'Relaxed',
#  'Lanyard',
#  'Coaster',
#  'Books and Zines',
#  'Indoor',
#  'NHL',
#  'Soccer',
#  'Reference',
#  'Posters & Prints',
#  'Nail Tools',
#  'Leash',
#  'Boyfriend',
#  'Baby Seats',
#  'Car',
#  'Televisions',
#  'Vases',
#  'Area Rugs & Pads',
#  'Tray',
#  'Wine, Beer & Beverage Coolers',
#  'Flare',
#  'Dress - Flat Front',
#  'Trench',
#  'Prenatal Monitoring Devices',
#  'Easter',
#  'Performance Parts & Accessories',
#  'Toy Remote Control & Play Vehicles',
#  'Varsity',
#  'Travel Beds',
#  'Tennis & Racquets',
#  'Board Shorts',
#  'Dress',
#  'Hands & Nails',
#  '75 To 100 Years',
#  'Action, Adventure',
#  'Pendant',
#  'Cabinet Locks & Straps',
#  'Golf Balls',
#  'Lights & Lighting Accessories',
#  'Tweezers',
#  'Animal',
#  'Bags & Cases',
#  'Sweatercoat',
#  'Needlepoint',
#  'Skateboard',
#  'Storage & Organization',
#  'Teething Relief',
#  'Stamps',
#  'Sports & Outdoor Play',
#  'Gloves',
#  'Mirrors',
#  'Basketball',
#  'Apron',
#  'Walkers',
#  'Skirts, Skorts & Dresses',
#  'Snowboard',
#  'GPS Units & Equipment',
#  'Linens',
#  'Soaps & Cleansers',
#  'Sculptures',
#  'Hockey',
#  'Oxfords',
#  'Instrument Accessories',
#  'Fabric',
#  'Home Decor',
#  'Parka',
#  'Bead',
#  'Vest, Sleeveless',
#  'Laundry Storage & Organization',
#  'Guitars',
#  'Patch',
#  'Interior Accessories',
#  "St Patrick's",
#  'Window Treatments',
#  'Corset',
#  'Golf Apparel',
#  'Scale Dollhouse Miniature',
#  'Skin Care',
#  'Clothing',
#  'Pin',
#  'Biographies & Memoirs',
#  'Outdoor',
#  'Kitchen',
#  'Swim Trunks',
#  'Bathing Accessories',
#  'Food Service Equipment & Supplies',
#  'Christian Books & Bibles',
#  'Decorative Pillows',
#  'Shampoo',
#  'Two Button',
#  'Bed Pillows',
#  'Home Speakers & Subwoofers',
#  'Cake Toppers',
#  'Baskets & Bins',
#  'Sci-Fi, Fantasy',
#  'Magic',
#  'Stationery & Party Supplies',
#  'Quilts',
#  'Tricycles, Scooters & Wagons',
#  'Teacup',
#  'Clock',
#  'Changing Pads & Covers',
#  'Health',
#  'Microphones & Accessories',
#  'Basic Supplies',
#  'Tripods & Supports',
#  'Wool',
#  'Embroidery',
#  'Bath Rugs',
#  'Home Surveillance',
#  'Space Heaters',
#  'Box',
#  'Glassware',
#  'Rainwear',
#  'Sweeping',
#  'Family Planning Tests',
#  'Baby & Child Care',
#  'Other Accessories',
#  'GPS Accessories & Mounts',
#  'Leather',
#  'Knitting Supplies',
#  'Corduroys',
#  'Board, Surf',
#  'History',
#  'Studio Recording Equipment',
#  'Athletic Apparel',
#  'Shampoo Plus Conditioner',
#  'Jacket',
#  'Baggy, Loose',
#  'Fans',
#  'Washcloths & Towels',
#  'Art',
#  'Biography',
#  'Shopping Cart Covers',
#  'Standard',
#  'Scarf',
#  'Linen',
#  'Flight',
#  'Sun Protection',
#  'Skirt Suit',
#  'One Button',
#  'Pet Lover',
#  'Track & Sweat Suits',
#  'Keyboards',
#  'Sewing',
#  'Electrical Safety',
#  'Cuff Links',
#  'Binoculars & Telescopes',
#  'Belt',
#  'Papermaking',
#  'Vests',
#  'Stringed Instruments',
#  'Bowls',
#  'Snowsuits & Bibs',
#  'Hat',
#  'Postcard',
#  'Breastfeeding Pillows & Stools',
#  'Home Audio',
#  'Bathing Tubs & Seats',
#  'Travel Systems',
#  'Printers, Scanners & Supplies',
#  'Full Skirt',
#  'Change Purse',
#  'Politics & Social Sciences',
#  'Children',
#  'Washers & Dryers',
#  'Air Purifiers',
#  'Teethers',
#  'Decorative Pillows, Inserts & Covers',
#  'Pillows & Stools',
#  'Kitchen Knives & Cutlery Accessories',
#  'Thermal Underwear',
#  'Poster',
#  'Shrug',
#  'Dress Suit',
#  'Religion & Spirituality',
#  'Nursery Décor',
#  'Novelty & Gag Toys',
#  'Racks, Shelves & Drawers',
#  'Porcelain',
#  'Cage',
#  'Fiction',
#  'Maternity',
#  'Print',
#  'Yarn',
#  'Gift Wrap',
#  'Bed',
#  'Wallet',
#  'Water Sports',
#  'Lenses & Filters',
#  'Bedroom Furniture',
#  'Crafting',
#  'Nasal Aspirators',
#  'Car Care',
#  'Toothbrushes',
#  'Mattress Pads',
#  'Decorations',
#  'Patriotic',
#  'Humidifiers & Vaporizers',
#  'Housewares',
#  'Birthday',
#  'Track & Field',
#  'Journal',
#  'Strength training',
#  'Puzzle',
#  'Microwaves',
#  'Hair Loss Products',
#  'Dress - Pleat',
#  'Illustration',
#  'Strategy Guides',
#  'Poetry',
#  'Historical, Military',
#  'DJ, Electronic Music & Karaoke',
#  'Backpack',
#  'Car Speakers & Systems',
#  'Feeding',
#  'Salt and Pepper Shakers',
#  'Paper Towels',
#  'Air Conditioners',
#  'Car Stereos & Components',
#  'Irons & Ironing Boards',
#  'Science & Math',
#  'Hair Relaxers',
#  'Camera',
#  'Replacement Parts & Tools',
#  'Mopping',
#  'Baguette',
#  'Signs',
#  'Cabochon',
#  'Calendar',
#  'Sweaters',
#  'Epilators',
#  'Watch',
#  'Cross Stitch',
#  'Swim Briefs',
#  'Vase',
#  'Bass Guitars',
#  'Harnesses & Leashes',
#  'Wall Hanging',
#  'Lighting',
#  'Carving',
#  'Case',
#  'Engineering & Transportation',
#  'How to',
#  'Peasant',
#  'Lighting & Studio',
#  'Shirt',
#  'Motorcycle & Powersports',
#  'Bags and Purses',
#  'Notebook',
#  'Equipment',
#  'Dress Shorts',
#  'Amplifiers & Effects',
#  'Hip Bag',
#  'Drums & Percussion',
#  'Travel Bathing Kits',
#  'Collages',
#  'Favors',
#  'Dehumidifiers',
#  'Three Button',
#  'Polo',
#  'Grooming & Healthcare Kits',
#  'Training Pants',
#  'Magnet',
#  'Telephone',
#  'Lacrosse',
#  'Hawaiian',
#  'Religious',
#  'Outdoor Safety',
#  'Wide Leg',
#  'Personalized',
#  'Joggers',
#  'Tshirt',
#  'Toiletry Kits',
#  'Ornaments',
#  'Golf Shoes',
#  "Kids' Furniture",
#  'Trash Bags',
#  'Nursery Bedding',
#  'Diaper Bag',
#  'Videogame',
#  'Planter',
#  'Potties & Seats',
#  'Automotive Enthusiast Merchandise',
#  'Buckle',
#  'Printmaking',
#  'Photographs',
#  'Casserole',
#  'Shams, Bed Skirts & Bed Frame Draperies',
#  'Plate',
#  'Garage Storage & Organization',
#  'Tires & Wheels',
#  'Instrument',
#  'Paper',
#  'Bowling',
#  'Refrigerators',
#  'Inflatable Beds',
#  'Kitchen Storage & Organization',
#  'Tiered',
#  'Other Furniture',
#  'Frame',
#  'Teapot',
#  "New Year's",
#  'Thermometers',
#  'Bathroom',
#  'Television',
#  'Laptop',
#  'Living Room Furniture',
#  "Kids' Bath",
#  'Sleep Positioners',
#  'Accessory',
#  'Magnets',
#  'Humor',
#  'Slipcovers',
#  'Bathroom Safety',
#  'Small Animal',
#  'Flatware',
#  'Diaper Stackers & Caddies',
#  'Bubble Bath',
#  'Gift Sets',
#  'Hair Perms & Texturizers',
#  'Skirts',
#  'Track Jacket',
#  'Paperweights',
#  'Outerwear',
#  'Custom',
#  'Finding',
#  'Maternity Pillows',
#  'Invitations',
#  'Live Sound & Stage',
#  'Graphic Design',
#  'Cream and Sugar Set',
#  'Dinnerware Set',
#  'Draft Stoppers',
#  'Comic',
#  'Nonfiction',
#  'Tuxedo',
#  'Lithographs, Etchings & Woodcuts',
#  'Car Subwoofers',
#  'Activity Centers & Entertainers',
#  'Pitcher',
#  'Button',
#  'Shawl',
#  'Bedspreads & Coverlets',
#  'Gadget',
#  'Paint, Body & Trim',
#  'Carpenter',
#  'Guest Books',
#  'Toys',
#  'Stained Glass',
#  'Block',
#  'Bouquets',
#  'Replacement Parts',
#  'Denim',
#  'Golf Bags',
#  'Tape',
#  'Storage Cabinets',
#  'Furniture',
#  'Art Doll',
#  'Bubble',
#  'Brushes',
#  'Child Friendly',
#  'Car Video',
#  'Brass Instruments',
#  'Safety Caps',
#  'Fireplaces & Accessories',
#  'Presentation',
#  'Doll Clothes',
#  'Human Figure Doll',
#  'Suits & Blazers',
#  'Beads',
#  'Home Entertainment Furniture',
#  'Fantasy',
#  'Bath Linen Sets',
#  'Pillow',
#  'Day of the Dead',
#  'Badminton',
#  'Kitchen Safety',
#  'Knitting',
#  'Lightweight',
#  'Decorating',
#  'Flashes & Flash Accessories',
#  'Garbage Disposals',
#  'Plush',
#  'Planters',
#  'Office',
#  'Gates & Doorways',
#  'Boxes',
#  'Carpenter, Utility',
#  'Afghan',
#  'Trash & Recycling',
#  'Pillows',
#  'Playard Bedding',
#  'Instructional',
#  'Changing Kits',
#  'Crochet',
#  'RV Parts & Accessories',
#  'Educational',
#  'Origami',
#  'Band & Orchestra',
#  'Chain',
#  'Pattern',
#  'Home Brewing & Wine Making',
#  'Doll Clothing',
#  'Figurines',
#  'Double Breasted',
#  'Table',
#  'Hair Coloring Tools',
#  'Music',
#  'Illustrated',
#  'Prams',
#  'Car Security & Convenience',
#  "Women's Golf Clubs",
#  'Dusting',
#  'Freezers & Ice Makers',
#  'Basket',
#  'Trim',
#  'Oils & Fluids',
#  'Religion',
#  'Bed in a Bag',
#  'Storage',
#  'Blanket',
#  'Powders & Lotions',
#  'Non-Slip Bath Mats',
#  'Something Blue',
#  'House',
#  'Cleaning',
#  'Handkerchief',
#  'Animals',
#  'Scifi',
#  'Tiles',
#  'Mixed Media',
#  'Sponges',
#  'Felted',
#  'Aceo',
#  'Frames',
#  'Fixture',
#  'Serving',
#  'Beading',
#  'Grooming',
#  'Seat Covers',
#  'Advertisement',
#  'Pad',
#  'Nail Care',
#  'Holiday Décor Storage',
#  'Dishes',
#  'Coasters',
#  'Fabric Postcard',
#  'Toddler',
#  'Chair',
#  'Candles',
#  'Bathroom Furniture Sets',
#  'Price Guides & Publications',
#  'Paper Ephemera',
#  'Horror',
#  'Nursery Furniture',
#  'Light',
#  'Patchwork',
#  'Tag',
#  'Handmade',
#  'Primitive',
#  'Necktie',
#  'Bicycle Child Seats & Trailers',
#  'Sport',
#  'Home Bar Furniture',
#  'Storage Solutions',
#  'Novelty',
#  'Pot Holder',
#  'Boating',
#  'Map',
#  'Shelf',
#  'Entertaining',
#  'Scale Models',
#  'Competitive Swimwear',
#  'International Publications',
#  'Cozy',
#  'Miniature',
#  'St Patricks',
#  'Fashion Dolls Apparel',
#  'Butter Dish',
#  'Mirror',
#  'Just Married',
#  'Cotton & Swabs',
#  'Pet Food',
#  'Bathroom Furniture',
#  'Cuff',
#  'Hanukkah',
#  'Feather Beds',
#  'Burning',
#  'Compact',
#  'Quilt',
#  'New Years',
#  'Edge & Corner Guards',
#  'Doorstops',
#  'Seasonal',
#  'Bathroom Shelves',
#  "Kids' Flatware",
#  'Towel',
#  'Crib Netting',
#  'Four Button',
#  'Entertainment',
#  'Platter',
#  'Zipper',
#  'Step Stools',
#  'Dishwashers',
#  'Bear',
#  'Artist Bears',
#  'Doormats',
#  'Ephemera']

# %% [markdown]
# Distribucija cijene u prvom levelu kategorije.

# %%
plt.figure(figsize = (20, 8))
sns.boxplot(x = data.subcat1, y = np.log(data.price+1))

# %%
data.groupby('subcat1')['price'].describe()
# Out:
#                            count       mean        std  min   25%   50%   75%  \
# subcat1
# Beauty                  207828.0  19.671536  21.360135  0.0  10.0  15.0  24.0
# Electronics             122690.0  35.173922  65.419784  0.0   9.0  15.0  31.0
# Handmade                 30842.0  18.156572  27.758289  0.0   6.0  12.0  20.0
# Home                     67871.0  24.536599  24.417061  0.0  12.0  18.0  29.0
# Kids                    171689.0  20.642315  22.730876  0.0  10.0  14.0  24.0
# Men                      93680.0  34.708614  41.240057  0.0  14.0  21.0  40.0
# Other                    45351.0  20.809817  29.847758  0.0   9.0  14.0  23.0
# Sports & Outdoors        25342.0  25.532219  29.302234  0.0  11.0  16.0  28.0
# Vintage & Collectibles   46530.0  27.339426  53.507495  0.0  10.0  16.0  27.0
# Women                   664385.0  28.885496  39.443853  0.0  12.0  19.0  33.0
#
#                            max
# subcat1
# Beauty                  2000.0
# Electronics             1909.0
# Handmade                1750.0
# Home                     848.0
# Kids                     809.0
# Men                     1309.0
# Other                   1400.0
# Sports & Outdoors        915.0
# Vintage & Collectibles  1709.0
# Women                   2009.0

# %%
data['subcat1'].value_counts(1)
# Out:
# Women                     0.450062
# Beauty                    0.140785
# Kids                      0.116304
# Electronics               0.083112
# Men                       0.063460
# Home                      0.045977
# Vintage & Collectibles    0.031520
# Other                     0.030721
# Handmade                  0.020893
# Sports & Outdoors         0.017167
# Name: subcat1, dtype: float64

# %% [markdown]
# *Women* i *Beauty* su najzastupljenije glavne kategorije (ukupno 56%).
# *Electronics* kategorija ima najveću standarnu devijaciju

# %%
plt.figure(figsize=(17,10))
sns.countplot(y = data['subcat1'], order = data['subcat1'].value_counts().index, orient = 'v')
plt.title('Top 10 Categories', fontsize = 25)
plt.ylabel('Main Category', fontsize = 20)
plt.xlabel('Number of Items in Main Category', fontsize = 20)
plt.show()

# %%
# Create a "no_brand" column 
data['no_brand'] = data['brand_name'].isnull()

f, ax = plt.subplots(figsize=(17, 10))
sns.countplot(y='subcat1', hue='no_brand', data=data)
plt.title('Category Distribution With/Without Brand')
plt.show()

# %% [markdown]
# Distribucija cijene u drugom i trećem levelu kategorije.

# %%
sub1 = data.groupby(["subcat2"], as_index = True).median().price.sort_values(ascending = False)
sub2 = data.groupby(["subcat3"], as_index = True).median().price.sort_values(ascending = False)

f, ax = plt.subplots(1,2,figsize=(15,5))
sns.distplot(sub1, ax=ax[0])
ax[0].set_title("Sub category 1")
sns.distplot(sub2, ax=ax[1])
ax[1].set_title("Sub category 2")
# Out:
# Text(0.5, 1.0, 'Sub category 2')

# %% [markdown]
# Još malo analize cijene...

# %%
data.price.describe()
# Out:
# count    1.482535e+06
# mean     2.673752e+01
# std      3.858607e+01
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.700000e+01
# 75%      2.900000e+01
# max      2.009000e+03
# Name: price, dtype: float64

# %%
# Mozemo li iskoristiti neka svojstva kvantila cijene kao nove featurese?
bins = [0, 10, 17, 29, 2001]
labels = ['q1','q2','q3','q4']
data['price_bin'] = pd.cut(data['price'], bins=bins, labels=labels)
data.groupby('price_bin')['price'].describe()
# Out:
#               count       mean        std   min   25%   50%   75%     max
# price_bin
# q1         375615.0   7.715192   2.077888   3.0   6.0   8.0  10.0    10.0
# q2         378177.0  13.842940   1.794584  10.5  12.0  14.0  15.0    17.0
# q3         359743.0  22.555694   3.337832  17.5  20.0  22.0  25.0    29.0
# q4         368123.0  63.527701  63.508250  29.5  35.0  45.0  66.0  2000.0

# %%
CAT_MIN = 5
STD_SIGMAS = 2
cats_stats = data.groupby(['category_name', 'brand_name', 'shipping']).agg({'category_name': len,
                                               'price_log': [np.median, np.mean, np.std]})
cats_stats.columns = ['price_log_median', 'price_log_mean', 'price_log_std','count']
#Removing categories without a minimum threshold of samples
cats_stats.drop(cats_stats[cats_stats['count'] < CAT_MIN].index, inplace=True)
cats_stats['price_log_std'] = cats_stats['price_log_std'].fillna(0)
cats_stats['price_log_conf_variance'] = cats_stats['price_log_std'] / cats_stats['price_log_mean']
cats_stats['count_log'] = np.log1p(cats_stats['count'])
cats_stats['min_expected_log_price'] = (cats_stats['price_log_mean'] - cats_stats['price_log_std']*STD_SIGMAS).clip(lower=1.0)
cats_stats['max_expected_log_price'] = (cats_stats['price_log_mean'] + cats_stats['price_log_std']*STD_SIGMAS)
# Out:
# C:\Users\Tatjana\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in log1p
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### Analiza varijable *shipping*

# %%
total = float(len(data.shipping))

plt.figure(figsize=(10,7))
ax = sns.countplot(data.shipping)
plt.title('Shipping fee paid by seller (1) or by buyer (0)', fontsize = 25)
plt.ylabel('Number of products', fontsize = 20)
plt.xlabel('')

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:.2f}%'.format((height/total)*100),
            ha="center")

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=data.shipping, y = data.price, showfliers=False, orient = 'v')
plt.title('Does shipping depend of prices ?', fontsize = 25)
plt.xlabel('Shipping fee paid by seller (1) or by buyer (0)', fontsize = 20)
plt.ylabel('Price without outliers', fontsize = 20)
# Out:
# Text(0, 0.5, 'Price without outliers')

# %% [markdown]
# ### Analiza varijable *item_description*

# %%
data['has_description'] = 1
data.loc[data['item_description']=='No description yet', 'has_description'] = 0
data.head()
data.loc[data.has_description ==1].head() #1400046
# Out:
#    train_id                              name  item_condition_id  \
# 1         1  Razer BlackWidow Chroma Keyboard                  3
# 2         2                    AVA-VIV Blouse                  1
# 3         3             Leather Horse Statues                  1
# 4         4              24K GOLD plated rose                  1
# 5         5  Bundled items requested for Ruie                  3
#
#                                        category_name  \
# 1  Electronics/Computers & Tablets/Components & P...
# 2                        Women/Tops & Blouses/Blouse
# 3                 Home/Home Décor/Home Décor Accents
# 4                            Women/Jewelry/Necklaces
# 5                                  Women/Other/Other
#
#                          brand_name  price  shipping  \
# 1  Razer BlackWidow Chroma Keyboard   52.0         0
# 2                    AVA-VIV Blouse   10.0         1
# 3                           unknown   35.0         1
# 4              24K GOLD plated rose   44.0         0
# 5                           unknown   59.0         0
#
#                                     item_description  price_log  \
# 1  This keyboard is in great condition and works ...   3.970292
# 2  Adorable top with a hint of lace and a key hol...   2.397895
# 3  New with tags. Leather horses. Retail for [rm]...   3.583519
# 4          Complete with certificate of authenticity   3.806662
# 5  Banana republic bottoms, Candies skirt with ma...   4.094345
#
#    has_description
# 1                1
# 2                1
# 3                1
# 4                1
# 5                1

# %% [markdown]
# Imamo 82489 'No description yet' vrijednosti varijable *item_description*.
#
# Ima li razlike u distribuciji cijene kada imamo ili nemamo opis?

# %%
plt.figure(figsize=(15, 7))
bins=50
plt.hist(data[data['has_description']==1]['price'], bins, range=[0,250],
         alpha=0.6, label='price when has_description==1')
plt.hist(data[data['has_description']==0]['price'], bins, range=[0,250],
         alpha=0.6, label='price when has_description==0')
plt.title('Train price X has_description type distribution', fontsize=15)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Samples', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# Analizom ovog histograma vidimo da je distribucija cijene kada nema opisa vrlo slična distribuciji kada imamo opis, ako uzmemo u obzir da je veličina uzoraka u histogramima jako različita. Normalizirani histogram nam može bolje pokazati sličnost.

# %%
plt.figure(figsize=(15, 10))
bins=50
plt.hist(data[data['has_description']==1]['price'], bins, density=True, range=[0,250],
         alpha=0.6, label='price when has_description==1')
plt.hist(data[data['has_description']==0]['price'], bins, density=True, range=[0,250],
         alpha=0.6, label='price when has_description==0')
plt.title('Train price X has_description type distribution', fontsize=15)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Samples', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
df=data
df = df[~df['item_description'].isnull()]
df = df[df['item_description']!='No description yet']

def preprocess(ReviewText):
    ReviewText = ReviewText.str.replace("(<br/>)", "")
    ReviewText = ReviewText.str.replace('(<a).*(>).*(</a>)', '')
    ReviewText = ReviewText.str.replace('(&amp)', '')
    ReviewText = ReviewText.str.replace('(&gt)', '')
    ReviewText = ReviewText.str.replace('(&lt)', '')
    ReviewText = ReviewText.str.replace('(\xa0)', ' ')  
    return ReviewText

df['item_description'] = preprocess(df['item_description'])

df.insert(loc=len(df.columns), column='polarity', value=0)
df.insert(loc=len(df.columns), column='word_count', value=0)

# %%
df['polarity'] = df['item_description'].map(lambda text: TextBlob(text).sentiment.polarity)
df['description_length'] = df['item_description'].astype(str).apply(len)
df['word_count'] = df['item_description'].apply(lambda x: len(str(x).split()))

# %%
data.loc[data.has_description ==0].shape #82489
# Out:
# (82489, 10)

# %%
print('Pet nasumičnih opisa najpozitivnijeg tona: \n')
cl = df.loc[df.polarity == 1, ['item_description']].sample(5).values
for c in cl:
    print(c[0])
# Out:
# Pet nasumičnih opisa najpozitivnijeg tona:
#
# Box in excellent condition.
# Size XS Never worn Purchased from the Chicago location All sequins are perfectly in place
# Great condition!
# Size 7 Never worn Perfect condition
# Never worn great condition!

# %%
print('Pet nasumičnih opisa neutralnog tona: \n')
c2 = df.loc[df.polarity == 0, ['item_description']].sample(5).values
for c in c2:
    print(c[0])
# Out:
# Pet nasumičnih opisa neutralnog tona:
#
# Lululemon crb tank heather blue color reversible
# Oversized Vintage windbreaker
# Real suede, worn only a few times Kenneth Cole
# SGA Mardi Gras King Cake 8+ oz Will include extras!
# Buckhead Bettie's brand.

# %%
print('Pet nasumičnih opisa negativnog tona: \n')
c3 = df.loc[df.polarity == -1, ['item_description']].sample(5).values
for c in c3:
    print(c[0])
# Out:
# Pet nasumičnih opisa negativnog tona:
#
# For victoria. Chicco carseat without base!
# Evil Wizard from series 13. Comes with everything in this photo.
# Bag of wood bead and evil eyes
# Ninja Shadow of Darkness Evil Zone Crash Bash
# Stands about 19" tall. Hang necklaces, bracelets, and earrings on the staggered branches, and keep rings, stud earrings, etc. in the tray at the base. No scratches or flaws. Jewelry not included and/or for sale!

# %%
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Polarnost')
plt.ylabel('Broj opisa')
plt.title('Distribucija polariteta sentimenta')
plt.hist(df['polarity'], color = 'blue', edgecolor = 'black',
    bins = 200)
plt.show()

# %%
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Broj riječi u opisu')
plt.ylabel('Broj opisa')
plt.title('Distribucija broja riječi')
plt.hist(df['word_count'], color = 'blue', edgecolor = 'black',
    bins = 200)
plt.show()

# %%
df['polarity'].corr(df['price'])
# Out:
# 0.014931981714400456

# %%
df['word_count'].corr(df['price'])
# Out:
# 0.04454084212518175

# %% [markdown]
# Tražimo najčešće korištene riječi u opisima

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words = 'english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(df['item_description'], 20)
for word, freq in common_words:
    print(word, freq)
df2 = pd.DataFrame(common_words, columns = ['item_description' , 'count'])
# Out:
# new 499697
# size 456225
# brand 274491
# free 271222
# condition 256095
# shipping 227052
# rm 225061
# worn 187194
# used 184345
# great 154554
# black 153516
# price 151228
# bundle 126193
# color 123810
# pink 123012
# small 117644
# like 114691
# good 105608
# box 101634
# tags 101427

# %%
df2.plot.barh(x='item_description', y='count', rot=0)

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['item_description'], 20)
for word, freq in common_words:
    print(word, freq)
df3 = pd.DataFrame(common_words, columns = ['item_description' , 'count'])
# Out:
# brand new 238158
# free shipping 116795
# price firm 68282
# great condition 64385
# good condition 63990
# new tags 62223
# free home 47765
# smoke free 46510
# like new 45747
# size small 42089
# victoria secret 40429
# size medium 36084
# excellent condition 35089
# bundle save 34914
# new box 29254
# size large 28783
# super cute 27705
# new used 27312
# rm rm 25932
# new worn 22421

# %%
df3.plot.barh(x='item_description', y='count', rot=0)

# %% [markdown]
# ## Data prepare

# %%
# handle_missing_values - Basic data imputation of missing values
def handle_missing_values(df):
    df['category_name'].fillna(value='missing', inplace=True)
    df['brand_name'].fillna(value='None', inplace=True)
    df['item_description'].fillna(value='None', inplace=True)

# %%
# to_categorical - Converts Categorical Features 
def to_categorical(df):
    df['brand_name'] = df['brand_name'].astype('category')
    df['category_name'] = df['category_name'].astype('category')
    df['item_condition_id'] = df['item_condition_id'].astype('category')

# %%
#data.drop(columns=['category_name'],inplace=True)
#data.head()
